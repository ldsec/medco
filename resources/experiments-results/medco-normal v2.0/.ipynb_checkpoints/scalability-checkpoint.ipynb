# %%
file = open("./scalability/queryA/10.txt","r") 

#tagging
split_tag = "Query tagging&quot;:"

with file as f:
    for line in f:
        print line
        break
        #cnt = line.split(split_tag)
        #print cnt.split(",")[0]
        
file.close()
# Out:
#         <description>{&quot;Hospital 3&quot;:{&quot;pub_key&quot;:&quot;eQviK90cvJ2lRx8ox6GgQKFmOtbgoG9RXa7UnmemtRA=&quot;,&quot;enc_count_result&quot;:&quot;c3Z6Db3ram2EEokLoK5e75mb56HloAyYfyUqWPwEe8uhtStdZg2heq4raP5kh0HUBch6VwhzON5hyD2tWuqKtw==&quot;,&quot;times&quot;:{&quot;overall&quot;:{&quot;&quot;:21119},&quot;steps&quot;:{&quot;User information retrieval&quot;:0,&quot;Query parsing/splitting&quot;:2,&quot;Query tagging&quot;:312,&quot;i2b2 query&quot;:19609,&quot;i2b2 patient set retrieval&quot;:84},&quot;DDTRequest execution time&quot;:21,&quot;DDTRequest communication time&quot;:247,&quot;DDTRequest parsing time&quot;:7,&quot;AggRequest execution time&quot;:37,&quot;AggRequest communication time&quot;:993,&quot;AggRequest parsing time&quot;:1,&quot;AggRequest aggregation time&quot;:0}}}</description>
#
# ...
